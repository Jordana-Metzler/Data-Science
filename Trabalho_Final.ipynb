# %% [markdown]
# <a href="https://colab.research.google.com/github/Jordana-Metzler/Data-Science/blob/main/Trabalho_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Projeto Data Science: *analisando os dados da Liga das Nações de vôlei feminino 2024*

# %% [markdown]
# ## Introdução
# Neste projeto, analisamos os dados da Liga das Nações de Vôlei Feminino 2024 (VNL 2024) com o objetivo de identificar os principais fundamentos que contribuíram para o desempenho das seleções participantes e destacar as jogadoras mais eficientes da competição. Como atleta de vôlei, trago minha vivência esportiva para interpretar os dados e validar as conclusões.

# %% [markdown]
# ## Objetivos
# - O que os dados revelam sobre o desempenho das seleções do pódio?
# - Quais foram as jogadoras mais eficientes?
# - Quais fundamentos (ataque, bloqueio, saque, defesa, recepção) se destacaram?
# - Como cada país performou nos fundamentos?
# - Como estão distribuídas as posições em quadra?
# - Visualizar os países participantes em um mapa interativo.

# %%
import pandas as pd
pd.set_option('display.expand_frame_repr', False)
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import folium

# %%
df = pd.read_csv("vnl.csv")
df.head(10)
# Out:
#          player country  age  attack  block  serve  set    dig  receive  \
# 0        Vargas     TUR   24   20.25   1.62   1.50  0.0   7.75     0.00
# 1          Koga     JPN   28   17.67   0.78   1.11  0.0  11.22     1.11
# 2       Van Ryk     CAN   25   16.44   0.89   1.11  0.0  12.56     0.11
# 3       Li Y.Y.     CHN   24   16.33   0.56   1.00  0.0   8.22     3.56
# 4          Gray     CAN   30   15.22   0.44   1.00  0.0   9.44     5.56
# 5         Egonu     ITA   25   14.60   2.40   2.20  0.0   4.20     0.00
# 6       Stysiak     POL   23   14.12   1.50   0.38  0.0   8.38     0.00
# 7          Gabi     BRA   30   14.12   0.88   1.12  0.0   9.50     5.25
# 8      Ishikawa     JPN   24   13.78   0.56   0.56  0.0   7.67     4.11
# 9  Ana Cristina     BRA   20   12.62   1.38   0.88  0.0   6.75     4.62
#
#   position
# 0       OP
# 1       OH
# 2       OH
# 3       OH
# 4       OH
# 5       OP
# 6       OP
# 7       OH
# 8       OH
# 9       OH

# %%
#Renomeando colunas para português
df.rename(columns={
    "player": "jogadora",
    "country": "pais",
    "age": "idade",
    "attack": "ataque",
    "block": "bloqueio",
    "serve": "saque",
    "set": "levantamento",
    "dig": "defesa",
    "receive": "recepcao",
    "position": "posicao"
}, inplace=True)
df.head(10)
# Out:
#        jogadora pais  idade  ataque  bloqueio  saque  levantamento  defesa  \
# 0        Vargas  TUR     24   20.25      1.62   1.50           0.0    7.75
# 1          Koga  JPN     28   17.67      0.78   1.11           0.0   11.22
# 2       Van Ryk  CAN     25   16.44      0.89   1.11           0.0   12.56
# 3       Li Y.Y.  CHN     24   16.33      0.56   1.00           0.0    8.22
# 4          Gray  CAN     30   15.22      0.44   1.00           0.0    9.44
# 5         Egonu  ITA     25   14.60      2.40   2.20           0.0    4.20
# 6       Stysiak  POL     23   14.12      1.50   0.38           0.0    8.38
# 7          Gabi  BRA     30   14.12      0.88   1.12           0.0    9.50
# 8      Ishikawa  JPN     24   13.78      0.56   0.56           0.0    7.67
# 9  Ana Cristina  BRA     20   12.62      1.38   0.88           0.0    6.75
#
#    recepcao posicao
# 0      0.00      OP
# 1      1.11      OH
# 2      0.11      OH
# 3      3.56      OH
# 4      5.56      OH
# 5      0.00      OP
# 6      0.00      OP
# 7      5.25      OH
# 8      4.11      OH
# 9      4.62      OH

# %%
#Traduzindo valores da coluna de posição
df["posicao"] = df["posicao"].replace({
    "OH": "Ponteira",
    "OP": "Oposta",
    "MB": "Central",
    "S": "Levantadora",
    "L": "Líbero"
})
df.head(10)
# Out:
#        jogadora pais  idade  ataque  bloqueio  saque  levantamento  defesa  \
# 0        Vargas  TUR     24   20.25      1.62   1.50           0.0    7.75
# 1          Koga  JPN     28   17.67      0.78   1.11           0.0   11.22
# 2       Van Ryk  CAN     25   16.44      0.89   1.11           0.0   12.56
# 3       Li Y.Y.  CHN     24   16.33      0.56   1.00           0.0    8.22
# 4          Gray  CAN     30   15.22      0.44   1.00           0.0    9.44
# 5         Egonu  ITA     25   14.60      2.40   2.20           0.0    4.20
# 6       Stysiak  POL     23   14.12      1.50   0.38           0.0    8.38
# 7          Gabi  BRA     30   14.12      0.88   1.12           0.0    9.50
# 8      Ishikawa  JPN     24   13.78      0.56   0.56           0.0    7.67
# 9  Ana Cristina  BRA     20   12.62      1.38   0.88           0.0    6.75
#
#    recepcao   posicao
# 0      0.00    Oposta
# 1      1.11  Ponteira
# 2      0.11  Ponteira
# 3      3.56  Ponteira
# 4      5.56  Ponteira
# 5      0.00    Oposta
# 6      0.00    Oposta
# 7      5.25  Ponteira
# 8      4.11  Ponteira
# 9      4.62  Ponteira

# %%
#Criando colunas adicionais: pontos totais e jogadora_completa
df["pontos_totais"] = df["ataque"] + df["bloqueio"] + df["saque"]
df["jogadora_completa"] = df["jogadora"] + " (" + df["posicao"] + " - " + df["pais"] + ")"
df.head(10)
# Out:
#        jogadora pais  idade  ataque  bloqueio  saque  levantamento  defesa  recepcao   posicao  pontos_totais              jogadora_completa
# 0        Vargas  TUR     24   20.25      1.62   1.50           0.0    7.75      0.00    Oposta          23.37          Vargas (Oposta - TUR)
# 1          Koga  JPN     28   17.67      0.78   1.11           0.0   11.22      1.11  Ponteira          19.56          Koga (Ponteira - JPN)
# 2       Van Ryk  CAN     25   16.44      0.89   1.11           0.0   12.56      0.11  Ponteira          18.44       Van Ryk (Ponteira - CAN)
# 3       Li Y.Y.  CHN     24   16.33      0.56   1.00           0.0    8.22      3.56  Ponteira          17.89       Li Y.Y. (Ponteira - CHN)
# 4          Gray  CAN     30   15.22      0.44   1.00           0.0    9.44      5.56  Ponteira          16.66          Gray (Ponteira - CAN)
# 5         Egonu  ITA     25   14.60      2.40   2.20           0.0    4.20      0.00    Oposta          19.20           Egonu (Oposta - ITA)
# 6       Stysiak  POL     23   14.12      1.50   0.38           0.0    8.38      0.00    Oposta          16.00         Stysiak (Oposta - POL)
# 7          Gabi  BRA     30   14.12      0.88   1.12           0.0    9.50      5.25  Ponteira          16.12          Gabi (Ponteira - BRA)
# 8      Ishikawa  JPN     24   13.78      0.56   0.56           0.0    7.67      4.11  Ponteira          14.90      Ishikawa (Ponteira - JPN)
# 9  Ana Cristina  BRA     20   12.62      1.38   0.88           0.0    6.75      4.62  Ponteira          14.88  Ana Cristina (Ponteira - BRA)

# %%
#Visão geral dos dados por seleção
df_paises = df.groupby("pais")[["ataque", "bloqueio", "saque", "defesa", "recepcao", "pontos_totais"]].mean().sort_values("pontos_totais", ascending=False).reset_index()
df_paises
# Out:
#    pais    ataque  bloqueio     saque    defesa  recepcao  pontos_totais
# 0   CHN  4.261538  0.656923  0.360000  3.925385  1.223077       5.278462
# 1   TUR  4.020000  0.874667  0.376000  3.664667  1.294667       5.270667
# 2   USA  3.957273  0.745000  0.304545  3.587273  1.234545       5.006818
# 3   BRA  3.685882  0.890588  0.297059  3.095294  1.019412       4.873529
# 4   CAN  3.641429  0.547143  0.404286  3.927857  0.841429       4.592857
# 5   DOM  3.687857  0.586429  0.291429  3.902143  0.900000       4.565714
# 6   JPN  3.816000  0.414667  0.289333  4.158667  1.206667       4.520000
# 7   ITA  3.346316  0.727895  0.432105  3.011579  1.000000       4.506316
# 8   SRB  3.492000  0.657000  0.329000  4.402500  1.825000       4.478000
# 9   POL  3.324737  0.776316  0.263158  3.160526  0.971053       4.364211
# 10  GER  3.396875  0.486875  0.408750  3.240000  1.145000       4.292500
# 11  NED  3.034375  0.575000  0.299375  3.023125  0.910000       3.908750
# 12  BUL  2.930000  0.413750  0.390000  3.096875  0.883125       3.733750
# 13  KOR  2.508571  0.460000  0.220714  3.015714  0.690000       3.189286
# 14  THA  2.802105  0.177368  0.184211  3.191053  1.269474       3.163684
# 15  FRA  2.321667  0.440556  0.241111  2.567778  1.322778       3.003333

# %%
#Países participantes
paises_coords = {
    'Brasil': [-14.2350, -51.9253],
    'Estados Unidos': [37.0902, -95.7129],
    'China': [35.8617, 104.1954],
    'Japão': [36.2048, 138.2529],
    'Polônia': [51.9194, 19.1451],
    'Turquia': [38.9637, 35.2433],
    'Itália': [41.8719, 12.5674],
    'Sérvia': [44.0165, 21.0059],
    'Alemanha': [51.1657, 10.4515],
    'Tailândia': [15.8700, 100.9925],
    'Canadá': [56.1304, -106.3468],
    'Países Baixos': [52.1326, 5.2913],
    'Coreia do Sul': [35.9078, 127.7669],
    'França': [46.6034, 1.8883],
    'República Dominicana': [18.7357, -70.1627],
    'Bulgária': [42.7339, 25.4858]
}

mapa = folium.Map(location=[20, 0], zoom_start=2)

# Adicionar os marcadores dos países
for pais, coords in paises_coords.items():
    folium.Marker(
        location=coords,
        popup=pais,
        tooltip=pais,
        icon=folium.Icon(color='blue', icon='globe')
    ).add_to(mapa)

# Mostrar o mapa

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b192311a028e1c36085784d5d55ccc1f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b192311a028e1c36085784d5d55ccc1f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b192311a028e1c36085784d5d55ccc1f = L.map(
#                 &quot;map_b192311a028e1c36085784d5d55ccc1f&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_322ed5e0adecf0f23686fa4cd567130c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_322ed5e0adecf0f23686fa4cd567130c.addTo(map_b192311a028e1c36085784d5d55ccc1f);
#
#
#             var marker_49f9af1f58a6b6c2e3b53b81c1393732 = L.marker(
#                 [-14.235, -51.9253],
#                 {
# }
#             ).addTo(map_b192311a028e1c36085784d5d55ccc1f);
#
#
#             var icon_d8f9cb95cabd8c2f0d9eba74f57aa8e5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;globe&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_971652575a0af03d90895661a25c2bfa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b593c09cad0067310500f5b9f898fb76 = $(`&lt;div id=&quot;html_b593c09cad0067310500f5b9f898fb76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brasil&lt;/div&gt;`)[0];
#                 popup_971652575a0af03d90895661a25c2bfa.setContent(html_b593c09cad0067310500f5b9f898fb76);
#
#
#
#         marker_49f9af1f58a6b6c2e3b53b81c1393732.bindPopup(popup_971652575a0af03d90895661a25c2bfa)
#         ;
#
#
#
#
#             marker_49f9af1f58a6b6c2e3b53b81c1393732.bindTooltip(
#                 `&lt;div&gt;
#                      Brasil
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_49f9af1f58a6b6c2e3b53b81c1393732.setIcon(icon_d8f9cb95cabd8c2f0d9eba74f57aa8e5);
#
#
#             var marker_d00a3542aadbcb0b4c9142aafc7afc34 = L.marker(
#                 [37.0902, -95.7129],
#                 {
# }
#             ).addTo(map_b192311a028e1c36085784d5d55ccc1f);
#
#
#             var icon_7b6a4392bd68188332301d77dc20bf3a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;globe&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7ac8d715cf123c528734e681e8da68a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a653ee7a78dd4d0af85227e8caf932b4 = $(`&lt;div id=&quot;html_a653ee7a78dd4d0af85227e8caf932b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estados Unidos&lt;/div&gt;`)[0];
#                 popup_7ac8d715cf123c528734e681e8da68a5.setContent(html_a653ee7a78dd4d0af85227e8caf932b4);
#
#
#
#         marker_d00a3542aadbcb0b4c9142aafc7afc34.bindPopup(popup_7ac8d715cf123c528734e681e8da68a5)
#         ;
#
#
#
#
#             marker_d00a3542aadbcb0b4c9142aafc7afc34.bindTooltip(
#                 `&lt;div&gt;
#                      Estados Unidos
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_d00a3542aadbcb0b4c9142aafc7afc34.setIcon(icon_7b6a4392bd68188332301d77dc20bf3a);
#
#
#             var marker_2d4a25fdee183284a6d91a6bdef4c276 = L.marker(
#                 [35.8617, 104.1954],
#                 {
# }
#             ).addTo(map_b192311a028e1c36085784d5d55ccc1f);
#
#
#             var icon_e3448c6e7191eb4641727f866f9dccb7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;globe&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_df2fd5b7e76a8253c60465b32b18f53a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0033d42d66889f6cb6eb93759e8be0a = $(`&lt;div id=&quot;html_b0033d42d66889f6cb6eb93759e8be0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;China&lt;/div&gt;`)[0];

# %%
#Gráfico de fundamentos por país
df_paises_melted = df_paises.melt(id_vars="pais", var_name="Fundamento", value_name="Média")
fig = px.bar(df_paises_melted, x="pais", y="Média", color="Fundamento",
             title="Média de Pontuação por Fundamento - Por Seleção",
             barmode="group", color_discrete_sequence=px.colors.qualitative.Pastel)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4f7c3fce-d8be-4a73-a74e-f860786bddbf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f7c3fce-d8be-4a73-a74e-f860786bddbf")) {                    Plotly.newPlot(                        "4f7c3fce-d8be-4a73-a74e-f860786bddbf",                        [{"alignmentgroup":"True","hovertemplate":"Fundamento=ataque\u003cbr\u003epais=%{x}\u003cbr\u003eMédia=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ataque","marker":{"color":"rgb(102, 197, 204)","pattern":{"shape":""}},"name":"ataque","offsetgroup":"ataque","orientation":"v","showlegend":true,"textposition":"auto","x":["CHN","TUR","USA","BRA","CAN","DOM","JPN","ITA","SRB","POL","GER","NED","BUL","KOR","THA","FRA"],"xaxis":"x","y":[4.2615384615384615,4.02,3.9572727272727275,3.685882352941176,3.641428571428572,3.687857142857143,3.8160000000000003,3.346315789473684,3.492,3.3247368421052634,3.396875,3.034375,2.93,2.5085714285714285,2.8021052631578947,2.3216666666666668],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Fundamento=bloqueio\u003cbr\u003epais=%{x}\u003cbr\u003eMédia=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"bloqueio","marker":{"color":"rgb(246, 207, 113)","pattern":{"shape":""}},"name":"bloqueio","offsetgroup":"bloqueio","orientation":"v","showlegend":true,"textposition":"auto","x":["CHN","TUR","USA","BRA","CAN","DOM","JPN","ITA","SRB","POL","GER","NED","BUL","KOR","THA","FRA"],"xaxis":"x","y":[0.6569230769230769,0.8746666666666667,0.745,0.8905882352941176,0.5471428571428572,0.5864285714285715,0.4146666666666667,0.7278947368421053,0.657,0.7763157894736842,0.486875,0.5750000000000001,0.41375,0.46,0.1773684210526316,0.44055555555555553],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Fundamento=saque\u003cbr\u003epais=%{x}\u003cbr\u003eMédia=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"saque","marker":{"color":"rgb(248, 156, 116)","pattern":{"shape":""}},"name":"saque","offsetgroup":"saque","orientation":"v","showlegend":true,"textposition":"auto","x":["CHN","TUR","USA","BRA","CAN","DOM","JPN","ITA","SRB","POL","GER","NED","BUL","KOR","THA","FRA"],"xaxis":"x","y":[0.36,0.37600000000000006,0.30454545454545456,0.29705882352941176,0.4042857142857143,0.2914285714285714,0.28933333333333333,0.43210526315789477,0.329,0.2631578947368421,0.40875,0.299375,0.39,0.22071428571428572,0.18421052631578946,0.2411111111111111],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Fundamento=defesa\u003cbr\u003epais=%{x}\u003cbr\u003eMédia=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"defesa","marker":{"color":"rgb(220, 176, 242)","pattern":{"shape":""}},"name":"defesa","offsetgroup":"defesa","orientation":"v","showlegend":true,"textposition":"auto","x":["CHN","TUR","USA","BRA","CAN","DOM","JPN","ITA","SRB","POL","GER","NED","BUL","KOR","THA","FRA"],"xaxis":"x","y":[3.9253846153846155,3.6646666666666667,3.5872727272727274,3.0952941176470588,3.927857142857143,3.902142857142857,4.158666666666667,3.011578947368421,4.4025,3.160526315789474,3.24,3.023125,3.096875,3.0157142857142856,3.1910526315789474,2.5677777777777777],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Fundamento=recepcao\u003cbr\u003epais=%{x}\u003cbr\u003eMédia=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"recepcao","marker":{"color":"rgb(135, 197, 95)","pattern":{"shape":""}},"name":"recepcao","offsetgroup":"recepcao","orientation":"v","showlegend":true,"textposition":"auto","x":["CHN","TUR","USA","BRA","CAN","DOM","JPN","ITA","SRB","POL","GER","NED","BUL","KOR","THA","FRA"],"xaxis":"x","y":[1.2230769230769232,1.2946666666666669,1.2345454545454546,1.0194117647058822,0.8414 ...

# %%
#Gráfico: Comparativo dos fundamentos entre as 4 melhores seleções
focus = df[df["pais"].isin(["ITA", "JPN", "POL", "BRA"])]
focus_grouped = focus.groupby("pais")[["ataque", "bloqueio", "saque", "defesa", "recepcao"]].mean().reset_index()
focus_melted = focus_grouped.melt(id_vars="pais", var_name="Fundamento", value_name="Média")
fig = px.bar(focus_melted, x="pais", y="Média", color="Fundamento",
             title="Comparativo dos Fundamentos: ITA x JPN x POL x BRA",
             barmode="group")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bcde4acf-0726-4aba-9514-134da78c0a5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bcde4acf-0726-4aba-9514-134da78c0a5d")) {                    Plotly.newPlot(                        "bcde4acf-0726-4aba-9514-134da78c0a5d",                        [{"alignmentgroup":"True","hovertemplate":"Fundamento=ataque\u003cbr\u003epais=%{x}\u003cbr\u003eMédia=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ataque","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"ataque","offsetgroup":"ataque","orientation":"v","showlegend":true,"textposition":"auto","x":["BRA","ITA","JPN","POL"],"xaxis":"x","y":[3.685882352941176,3.346315789473684,3.8160000000000003,3.3247368421052634],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Fundamento=bloqueio\u003cbr\u003epais=%{x}\u003cbr\u003eMédia=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"bloqueio","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"bloqueio","offsetgroup":"bloqueio","orientation":"v","showlegend":true,"textposition":"auto","x":["BRA","ITA","JPN","POL"],"xaxis":"x","y":[0.8905882352941176,0.7278947368421053,0.4146666666666667,0.7763157894736842],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Fundamento=saque\u003cbr\u003epais=%{x}\u003cbr\u003eMédia=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"saque","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"saque","offsetgroup":"saque","orientation":"v","showlegend":true,"textposition":"auto","x":["BRA","ITA","JPN","POL"],"xaxis":"x","y":[0.29705882352941176,0.43210526315789477,0.28933333333333333,0.2631578947368421],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Fundamento=defesa\u003cbr\u003epais=%{x}\u003cbr\u003eMédia=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"defesa","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"defesa","offsetgroup":"defesa","orientation":"v","showlegend":true,"textposition":"auto","x":["BRA","ITA","JPN","POL"],"xaxis":"x","y":[3.0952941176470588,3.011578947368421,4.158666666666667,3.160526315789474],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Fundamento=recepcao\u003cbr\u003epais=%{x}\u003cbr\u003eMédia=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"recepcao","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"recepcao","offsetgroup":"recepcao","orientation":"v","showlegend":true,"textposition":"auto","x":["BRA","ITA","JPN","POL"],"xaxis":"x","y":[1.0194117647058822,1.0,1.2066666666666668,0.9710526315789473],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444 ...

# %%
# Gráfico: Top 10 Jogadoras por Pontuação Total
df["jogadora_pais"] = df["jogadora"] + " (" + df["pais"] + ")"
top10_geral = df.sort_values("pontos_totais", ascending=False).head(10)
fig = px.bar(top10_geral, x="pontos_totais", y="jogadora_completa", color="pais", orientation='h',
             title="Top 10 Jogadoras - Pontuação Total",
             color_discrete_sequence=px.colors.qualitative.Pastel)
fig.update_layout(yaxis_categoryorder='total ascending')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a1777cb2-d203-4524-a926-06ff17e81dbb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1777cb2-d203-4524-a926-06ff17e81dbb")) {                    Plotly.newPlot(                        "a1777cb2-d203-4524-a926-06ff17e81dbb",                        [{"alignmentgroup":"True","hovertemplate":"pais=TUR\u003cbr\u003epontos_totais=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TUR","marker":{"color":"rgb(102, 197, 204)","pattern":{"shape":""}},"name":"TUR","offsetgroup":"TUR","orientation":"h","showlegend":true,"textposition":"auto","x":[23.37],"xaxis":"x","y":["Vargas (Oposta - TUR)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=JPN\u003cbr\u003epontos_totais=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"JPN","marker":{"color":"rgb(246, 207, 113)","pattern":{"shape":""}},"name":"JPN","offsetgroup":"JPN","orientation":"h","showlegend":true,"textposition":"auto","x":[19.560000000000002,14.9],"xaxis":"x","y":["Koga (Ponteira - JPN)","Ishikawa (Ponteira - JPN)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=ITA\u003cbr\u003epontos_totais=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ITA","marker":{"color":"rgb(248, 156, 116)","pattern":{"shape":""}},"name":"ITA","offsetgroup":"ITA","orientation":"h","showlegend":true,"textposition":"auto","x":[19.2],"xaxis":"x","y":["Egonu (Oposta - ITA)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=CAN\u003cbr\u003epontos_totais=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CAN","marker":{"color":"rgb(220, 176, 242)","pattern":{"shape":""}},"name":"CAN","offsetgroup":"CAN","orientation":"h","showlegend":true,"textposition":"auto","x":[18.44,16.66],"xaxis":"x","y":["Van Ryk (Ponteira - CAN)","Gray (Ponteira - CAN)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=CHN\u003cbr\u003epontos_totais=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CHN","marker":{"color":"rgb(135, 197, 95)","pattern":{"shape":""}},"name":"CHN","offsetgroup":"CHN","orientation":"h","showlegend":true,"textposition":"auto","x":[17.889999999999997],"xaxis":"x","y":["Li Y.Y. (Ponteira - CHN)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=BRA\u003cbr\u003epontos_totais=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BRA","marker":{"color":"rgb(158, 185, 243)","pattern":{"shape":""}},"name":"BRA","offsetgroup":"BRA","orientation":"h","showlegend":true,"textposition":"auto","x":[16.12,14.88],"xaxis":"x","y":["Gabi (Ponteira - BRA)","Ana Cristina (Ponteira - BRA)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=POL\u003cbr\u003epontos_totais=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"POL","marker":{"color":"rgb(254, 136, 177)","pattern":{"shape":""}},"name":"POL","offsetgroup":"POL","orientation":"h","showlegend":true,"textposition":"auto","x":[16.0],"xaxis":"x","y":["Stysiak (Oposta - POL)"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#f ...

# %%
#Top 5 por ataque
top_ataque = df.sort_values("ataque", ascending=False).head(5)
fig = px.bar(top_ataque, x="ataque", y="jogadora_completa", color="pais", orientation='h',
             title="Top 5 - Ataque",
             color_discrete_sequence=px.colors.qualitative.Pastel)
fig.update_layout(yaxis_categoryorder='total ascending')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="228cc501-334b-4897-b596-f1d395729282" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("228cc501-334b-4897-b596-f1d395729282")) {                    Plotly.newPlot(                        "228cc501-334b-4897-b596-f1d395729282",                        [{"alignmentgroup":"True","hovertemplate":"pais=TUR\u003cbr\u003eataque=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TUR","marker":{"color":"rgb(102, 197, 204)","pattern":{"shape":""}},"name":"TUR","offsetgroup":"TUR","orientation":"h","showlegend":true,"textposition":"auto","x":[20.25],"xaxis":"x","y":["Vargas (Oposta - TUR)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=JPN\u003cbr\u003eataque=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"JPN","marker":{"color":"rgb(246, 207, 113)","pattern":{"shape":""}},"name":"JPN","offsetgroup":"JPN","orientation":"h","showlegend":true,"textposition":"auto","x":[17.67],"xaxis":"x","y":["Koga (Ponteira - JPN)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=CAN\u003cbr\u003eataque=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CAN","marker":{"color":"rgb(248, 156, 116)","pattern":{"shape":""}},"name":"CAN","offsetgroup":"CAN","orientation":"h","showlegend":true,"textposition":"auto","x":[16.44,15.22],"xaxis":"x","y":["Van Ryk (Ponteira - CAN)","Gray (Ponteira - CAN)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=CHN\u003cbr\u003eataque=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CHN","marker":{"color":"rgb(220, 176, 242)","pattern":{"shape":""}},"name":"CHN","offsetgroup":"CHN","orientation":"h","showlegend":true,"textposition":"auto","x":[16.33],"xaxis":"x","y":["Li Y.Y. (Ponteira - CHN)"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"tic ...

# %%
# Top 5 por Bloqueio
top_bloqueio = df.sort_values("bloqueio", ascending=False).head(5)
fig = px.bar(top_bloqueio, x="bloqueio", y="jogadora_completa", color="pais", orientation='h',
             title="Top 5 - Bloqueio",
             color_discrete_sequence=px.colors.qualitative.Pastel)
fig.update_layout(yaxis_categoryorder='total ascending')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="88610bcd-8a90-4f57-94b2-f948a0609615" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88610bcd-8a90-4f57-94b2-f948a0609615")) {                    Plotly.newPlot(                        "88610bcd-8a90-4f57-94b2-f948a0609615",                        [{"alignmentgroup":"True","hovertemplate":"pais=SRB\u003cbr\u003ebloqueio=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SRB","marker":{"color":"rgb(102, 197, 204)","pattern":{"shape":""}},"name":"SRB","offsetgroup":"SRB","orientation":"h","showlegend":true,"textposition":"auto","x":[4.12],"xaxis":"x","y":["Kurtagić (Central - SRB)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=POL\u003cbr\u003ebloqueio=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"POL","marker":{"color":"rgb(246, 207, 113)","pattern":{"shape":""}},"name":"POL","offsetgroup":"POL","orientation":"h","showlegend":true,"textposition":"auto","x":[4.0],"xaxis":"x","y":["Korneluk (Central - POL)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=BRA\u003cbr\u003ebloqueio=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BRA","marker":{"color":"rgb(248, 156, 116)","pattern":{"shape":""}},"name":"BRA","offsetgroup":"BRA","orientation":"h","showlegend":true,"textposition":"auto","x":[3.12],"xaxis":"x","y":["Carol (Central - BRA)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=TUR\u003cbr\u003ebloqueio=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TUR","marker":{"color":"rgb(220, 176, 242)","pattern":{"shape":""}},"name":"TUR","offsetgroup":"TUR","orientation":"h","showlegend":true,"textposition":"auto","x":[2.67],"xaxis":"x","y":["Güneş (Central - TUR)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=CAN\u003cbr\u003ebloqueio=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CAN","marker":{"color":"rgb(135, 197, 95)","pattern":{"shape":""}},"name":"CAN","offsetgroup":"CAN","orientation":"h","showlegend":true,"textposition":"auto","x":[2.56],"xaxis":"x","y":["Maglio (Central - CAN)"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[ ...

# %%
# Top 5 por Saque
top_saque = df.sort_values("saque", ascending=False).head(5)
fig = px.bar(top_saque, x="saque", y="jogadora_completa", color="pais", orientation='h',
             title="Top 5 - Saque",
             color_discrete_sequence=px.colors.qualitative.Pastel)
fig.update_layout(yaxis_categoryorder='total ascending')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="22357981-2821-4b72-bffb-f0baa5ac0698" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22357981-2821-4b72-bffb-f0baa5ac0698")) {                    Plotly.newPlot(                        "22357981-2821-4b72-bffb-f0baa5ac0698",                        [{"alignmentgroup":"True","hovertemplate":"pais=BUL\u003cbr\u003esaque=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BUL","marker":{"color":"rgb(102, 197, 204)","pattern":{"shape":""}},"name":"BUL","offsetgroup":"BUL","orientation":"h","showlegend":true,"textposition":"auto","x":[2.2],"xaxis":"x","y":["Nikolova M. (Oposta - BUL)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=ITA\u003cbr\u003esaque=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ITA","marker":{"color":"rgb(246, 207, 113)","pattern":{"shape":""}},"name":"ITA","offsetgroup":"ITA","orientation":"h","showlegend":true,"textposition":"auto","x":[2.2],"xaxis":"x","y":["Egonu (Oposta - ITA)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=GER\u003cbr\u003esaque=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GER","marker":{"color":"rgb(248, 156, 116)","pattern":{"shape":""}},"name":"GER","offsetgroup":"GER","orientation":"h","showlegend":true,"textposition":"auto","x":[1.78],"xaxis":"x","y":["Weitzel (Central - GER)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=TUR\u003cbr\u003esaque=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TUR","marker":{"color":"rgb(220, 176, 242)","pattern":{"shape":""}},"name":"TUR","offsetgroup":"TUR","orientation":"h","showlegend":true,"textposition":"auto","x":[1.5],"xaxis":"x","y":["Vargas (Oposta - TUR)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=THA\u003cbr\u003esaque=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"THA","marker":{"color":"rgb(135, 197, 95)","pattern":{"shape":""}},"name":"THA","offsetgroup":"THA","orientation":"h","showlegend":true,"textposition":"auto","x":[1.38],"xaxis":"x","y":["M. Chatchu-On (Ponteira - THA)"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222 ...

# %%
# Top 5 por Defesa
top_defesa = df.sort_values("defesa", ascending=False).head(5)
fig = px.bar(top_defesa, x="defesa", y="jogadora_completa", color="pais", orientation='h',
             title="Top 5 - Defesa",
             color_discrete_sequence=px.colors.qualitative.Pastel)
fig.update_layout(yaxis_categoryorder='total ascending')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="21a4c440-c01c-461b-af2a-3ef122374bb3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21a4c440-c01c-461b-af2a-3ef122374bb3")) {                    Plotly.newPlot(                        "21a4c440-c01c-461b-af2a-3ef122374bb3",                        [{"alignmentgroup":"True","hovertemplate":"pais=CAN\u003cbr\u003edefesa=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CAN","marker":{"color":"rgb(102, 197, 204)","pattern":{"shape":""}},"name":"CAN","offsetgroup":"CAN","orientation":"h","showlegend":true,"textposition":"auto","x":[12.56],"xaxis":"x","y":["Van Ryk (Ponteira - CAN)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=POL\u003cbr\u003edefesa=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"POL","marker":{"color":"rgb(246, 207, 113)","pattern":{"shape":""}},"name":"POL","offsetgroup":"POL","orientation":"h","showlegend":true,"textposition":"auto","x":[12.0],"xaxis":"x","y":["Szczygłowska (Líbero - POL)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=CHN\u003cbr\u003edefesa=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CHN","marker":{"color":"rgb(248, 156, 116)","pattern":{"shape":""}},"name":"CHN","offsetgroup":"CHN","orientation":"h","showlegend":true,"textposition":"auto","x":[11.78],"xaxis":"x","y":["Wang M.J. (Líbero - CHN)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=BRA\u003cbr\u003edefesa=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BRA","marker":{"color":"rgb(220, 176, 242)","pattern":{"shape":""}},"name":"BRA","offsetgroup":"BRA","orientation":"h","showlegend":true,"textposition":"auto","x":[11.62],"xaxis":"x","y":["Nyeme (Líbero - BRA)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=JPN\u003cbr\u003edefesa=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"JPN","marker":{"color":"rgb(135, 197, 95)","pattern":{"shape":""}},"name":"JPN","offsetgroup":"JPN","orientation":"h","showlegend":true,"textposition":"auto","x":[11.33],"xaxis":"x","y":["Hayashi (Ponteira - JPN)"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"] ...

# %%
#Top 5 por Recepção
top_recepcao = df.sort_values("recepcao", ascending=False).head(5)
fig = px.bar(top_recepcao, x="recepcao", y="jogadora_completa", color="pais", orientation='h',
             title="Top 5 - Recepção",
             color_discrete_sequence=px.colors.qualitative.Pastel)
fig.update_layout(yaxis_categoryorder='total ascending')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8be6a649-3057-4e01-b00b-3c6d20d113ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8be6a649-3057-4e01-b00b-3c6d20d113ec")) {                    Plotly.newPlot(                        "8be6a649-3057-4e01-b00b-3c6d20d113ec",                        [{"alignmentgroup":"True","hovertemplate":"pais=SRB\u003cbr\u003erecepcao=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SRB","marker":{"color":"rgb(102, 197, 204)","pattern":{"shape":""}},"name":"SRB","offsetgroup":"SRB","orientation":"h","showlegend":true,"textposition":"auto","x":[11.0],"xaxis":"x","y":["Medved (Líbero - SRB)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=USA\u003cbr\u003erecepcao=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"USA","marker":{"color":"rgb(246, 207, 113)","pattern":{"shape":""}},"name":"USA","offsetgroup":"USA","orientation":"h","showlegend":true,"textposition":"auto","x":[10.0],"xaxis":"x","y":["Cook (Ponteira - USA)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=THA\u003cbr\u003erecepcao=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"THA","marker":{"color":"rgb(248, 156, 116)","pattern":{"shape":""}},"name":"THA","offsetgroup":"THA","orientation":"h","showlegend":true,"textposition":"auto","x":[8.25],"xaxis":"x","y":["M. Chatchu-On (Ponteira - THA)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=GER\u003cbr\u003erecepcao=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GER","marker":{"color":"rgb(220, 176, 242)","pattern":{"shape":""}},"name":"GER","offsetgroup":"GER","orientation":"h","showlegend":true,"textposition":"auto","x":[7.33],"xaxis":"x","y":["Stigrot (Ponteira - GER)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"pais=JPN\u003cbr\u003erecepcao=%{x}\u003cbr\u003ejogadora_completa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"JPN","marker":{"color":"rgb(135, 197, 95)","pattern":{"shape":""}},"name":"JPN","offsetgroup":"JPN","orientation":"h","showlegend":true,"textposition":"auto","x":[7.0],"xaxis":"x","y":["Hayashi (Ponteira - JPN)"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46 ...

# %%
#Distribuição de Posições em Quadra
df_pos = df["posicao"].value_counts().reset_index()
df_pos.columns = ["Posição", "Quantidade"]
fig = px.bar(df_pos, x="Posição", y="Quantidade",
             title="Distribuição de Posições em Quadra",
             color="Posição", color_discrete_sequence=px.colors.qualitative.Pastel)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2007222f-9777-4798-ac19-fb0c6ccbe10d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2007222f-9777-4798-ac19-fb0c6ccbe10d")) {                    Plotly.newPlot(                        "2007222f-9777-4798-ac19-fb0c6ccbe10d",                        [{"alignmentgroup":"True","hovertemplate":"Posição=%{x}\u003cbr\u003eQuantidade=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ponteira","marker":{"color":"rgb(102, 197, 204)","pattern":{"shape":""}},"name":"Ponteira","offsetgroup":"Ponteira","orientation":"v","showlegend":true,"textposition":"auto","x":["Ponteira"],"xaxis":"x","y":[85],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Posição=%{x}\u003cbr\u003eQuantidade=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Central","marker":{"color":"rgb(246, 207, 113)","pattern":{"shape":""}},"name":"Central","offsetgroup":"Central","orientation":"v","showlegend":true,"textposition":"auto","x":["Central"],"xaxis":"x","y":[67],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Posição=%{x}\u003cbr\u003eQuantidade=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Levantadora","marker":{"color":"rgb(248, 156, 116)","pattern":{"shape":""}},"name":"Levantadora","offsetgroup":"Levantadora","orientation":"v","showlegend":true,"textposition":"auto","x":["Levantadora"],"xaxis":"x","y":[43],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Posição=%{x}\u003cbr\u003eQuantidade=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Líbero","marker":{"color":"rgb(220, 176, 242)","pattern":{"shape":""}},"name":"Líbero","offsetgroup":"Líbero","orientation":"v","showlegend":true,"textposition":"auto","x":["Líbero"],"xaxis":"x","y":[39],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Posição=%{x}\u003cbr\u003eQuantidade=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oposta","marker":{"color":"rgb(135, 197, 95)","pattern":{"shape":""}},"name":"Oposta","offsetgroup":"Oposta","orientation":"v","showlegend":true,"textposition":"auto","x":["Oposta"],"xaxis":"x","y":[33],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777 ...

# %% [markdown]
# ## 📊 Análise: Os dados confirmam o pódio da VNL 2024?
#
# Com base nas estatísticas da Liga das Nações de Vôlei Feminino 2024, os dados confirmam o merecido pódio composto por **Itália**, **Japão** e **Polônia**. A **Itália** apresentou o desempenho mais equilibrado em todos os fundamentos, enquanto o **Japão** liderou com folga os fundamentos defensivos, que caracterizam o estilo de jogo, e a **Polônia**, por sua vez, teve um desempenho sólido especialmente nos bloqueios.
#
# Já a **seleção brasileira**, apesar de figurar entre as melhores em **ataques** e **saques**, teve um baixo aproveitamento nos **fundamentos defensivos** o que comprometeu seu rendimento, resultando na **4ª colocação**.
#
# Nos destaques individuais, **Egonu (ITA)** lidera em pontos, **Inoue** e **Kojima (JPN)** se sobressaem na recepção e defesa, e **Korneluk (POL)** no bloqueio. A análise mostra que **consistência nos fundamentos** foi o diferencial decisivo para o sucesso das equipes no torneio.

# %% [markdown]
# ## 🏅 Comparando a Seleção Ideal com a Seleção Oficial da VNL 2024
#
# Além da análise por país e fundamentos, também é possível observar os destaques individuais da competição. A Federação Internacional de Voleibol (FIVB) seleciona, ao final do torneio, uma **seleção do campeonato**, composta pelas atletas que mais se destacaram tecnicamente e taticamente em suas posições.
#
# Neste projeto, com base nos dados estatísticos da VNL 2024, construímos uma **seleção ideal baseada em desempenho quantitativo**.
#
# A seguir, comparamos essa seleção ideal com a **seleção oficial divulgada pela FIVB**, refletindo sobre as semelhanças e diferenças entre desempenho numérico e impacto real dentro da competição.

# %%
dados = {
    "Posição": ["Levantadora", "Oposta", "Ponteira 1", "Ponteira 2", "Central 1", "Central 2", "Líbero"],
    "Seleção Ideal (Dados)": [
        "Alessia Orro (ITA)",
        "Paola Egonu (ITA)",
        "Gabi Guimarães (BRA)",
        "Arisa Inoue (JPN)",
        "Agnieszka Korneluk (POL)",
        "Sarah Fahr (ITA)",
        "Manami Kojima (JPN)"
    ],
    "Seleção Oficial (VNL 2024)": [
        "Alessia Orro (ITA)",
        "Paola Egonu (ITA)",
        "Myriam Sylla (ITA)",
        "Sarina Koga (JPN)",
        "Sarah Fahr (ITA)",
        "Agnieszka Korneluk (POL)",
        "Manami Kojima (JPN)"
    ]
}

df_comparativo = pd.DataFrame(dados)

# Tabela comparativa
fig = go.Figure(data=[go.Table(
    header=dict(values=["Posição", "Seleção Ideal (Dados)", "Seleção Oficial (VNL 2024)"],
                fill_color='paleturquoise',
                align='left'),
    cells=dict(values=[
        df_comparativo["Posição"],
        df_comparativo["Seleção Ideal (Dados)"],
        df_comparativo["Seleção Oficial (VNL 2024)"]
    ],
    fill_color='lavender',
    align='left'))
])

fig.update_layout(title="Comparativo: Seleção Ideal X Seleção Oficial da VNL 2024")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="88636c3a-422d-442f-9e99-f16861a30e27" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88636c3a-422d-442f-9e99-f16861a30e27")) {                    Plotly.newPlot(                        "88636c3a-422d-442f-9e99-f16861a30e27",                        [{"cells":{"align":"left","fill":{"color":"lavender"},"values":[["Levantadora","Oposta","Ponteira 1","Ponteira 2","Central 1","Central 2","Líbero"],["Alessia Orro (ITA)","Paola Egonu (ITA)","Gabi Guimarães (BRA)","Arisa Inoue (JPN)","Agnieszka Korneluk (POL)","Sarah Fahr (ITA)","Manami Kojima (JPN)"],["Alessia Orro (ITA)","Paola Egonu (ITA)","Myriam Sylla (ITA)","Sarina Koga (JPN)","Sarah Fahr (ITA)","Agnieszka Korneluk (POL)","Manami Kojima (JPN)"]]},"header":{"align":"left","fill":{"color":"paleturquoise"},"values":["Posição","Seleção Ideal (Dados)","Seleção Oficial (VNL 2024)"]},"type":"table"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"erro ...

# %% [markdown]
# ### 🧠 Conclusão da Comparação
#
# A análise mostra que, em grande parte, a **seleção oficial da VNL 2024 coincide com os dados** estatísticos. Nomes como **Paola Egonu**, **Alessia Orro**, **Sarah Fahr** e **Agnieszka Korneluk** aparecem em ambas as seleções, confirmando seus desempenhos de destaque.
#
# As principais **diferenças** aparecem nas escolhas de ponteiras: enquanto os dados apontam para **Gabi Guimarães (BRA)** e **Arisa Inoue (JPN)** como mais eficientes em pontuação e regularidade, a seleção oficial optou por **Myriam Sylla (ITA)** e **Sarina Koga (JPN)**.
#
# Essa comparação reforça que **a performance estatística é essencial**, mas **a escolha da seleção oficial também leva em conta aspectos subjetivos** e qualitativos, como equilíbrio tático, protagonismo em jogos decisivos e contribuição coletiva para o sucesso da equipe.
